# %% [markdown]
# <a href="https://colab.research.google.com/github/DzhuJK/KOOK/blob/main/%D0%9B%D0%A06_%D0%9B%D0%B0%D1%86.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Фрактал «Крива Пеано»

# %%
import matplotlib.pyplot as plt
import math

class LSystem2D:
    def __init__(self, axiom, width, length, angle):
        self.axiom = axiom
        self.state = axiom
        self.width = width
        self.length = length
        self.angle = angle
        self.rules = {}

    def add_rules(self, *rules):
        for key, value in rules:
            self.rules[key] = value

    def generate_path(self, n_iter):
        for _ in range(n_iter):
            new_state = ""
            for char in self.state:
                if char in self.rules:
                    new_state += self.rules[char].lower()
                else:
                    new_state += char
            self.state = new_state.upper()

    def draw_turtle(self, start_pos, start_angle):
        x, y = start_pos
        current_angle = start_angle

        lines_x = []
        lines_y = []

        for move in self.state:
            if move == 'F':
                new_x = x + self.length * math.cos(math.radians(current_angle))
                new_y = y + self.length * math.sin(math.radians(current_angle))
                lines_x.extend([x, new_x, None])
                lines_y.extend([y, new_y, None])
                x, y = new_x, new_y
            elif move == '+':
                current_angle += self.angle
            elif move == '-':
                current_angle -= self.angle

        plt.figure(figsize=(10, 10))
        plt.plot(lines_x, lines_y, linewidth=self.width)
        plt.axis("equal")
        plt.axis("off")
        plt.show()

# --- Основна частина ---
pen_width = 1
f_len = 5
angle = 90
axiom = "X"

# Побудова кривої Пеано
l_sys = LSystem2D(axiom, pen_width, f_len, angle)
l_sys.add_rules(
    ("X", "XFYFX+F+YFXFY-F-XFYFX"),
    ("Y", "YFXFY-F-XFYFX+F+YFXFY")
)
l_sys.generate_path(3)
l_sys.draw_turtle((0, 0), 0)

# %% [markdown]
# Фрактал «Крива Леві»

# %%
import matplotlib.pyplot as plt
import math

class LSystem2D:
    def __init__(self, axiom, width, length, angle):
        self.axiom = axiom
        self.state = axiom
        self.width = width
        self.length = length
        self.angle = angle
        self.rules = {}

    def add_rules(self, *rules):
        for key, value in rules:
            self.rules[key] = value

    def generate_path(self, n_iter):
        for _ in range(n_iter):
            new_state = ""
            for char in self.state:
                if char in self.rules:
                    new_state += self.rules[char].lower()
                else:
                    new_state += char
            self.state = new_state.upper()

    def draw_turtle(self, start_pos, start_angle):
        x, y = start_pos
        current_angle = start_angle

        lines_x = []
        lines_y = []

        for move in self.state:
            if move == 'F':
                new_x = x + self.length * math.cos(math.radians(current_angle))
                new_y = y + self.length * math.sin(math.radians(current_angle))
                lines_x.extend([x, new_x, None])
                lines_y.extend([y, new_y, None])
                x, y = new_x, new_y
            elif move == '+':
                current_angle += self.angle
            elif move == '-':
                current_angle -= self.angle

        plt.figure(figsize=(10, 6))
        plt.plot(lines_x, lines_y, linewidth=self.width)
        plt.axis("equal")
        plt.axis("off")
        plt.show()

# --- Основна частина ---
pen_width = 1
f_len = 5
angle = 45
axiom = "F"

# Побудова кривої Леві
l_sys = LSystem2D(axiom, pen_width, f_len, angle)
l_sys.add_rules(
    ("F", "+F--F+")
)
l_sys.generate_path(15)
l_sys.draw_turtle((0, 0), 0)

# %% [markdown]
# Фрактал «Крива Госпера»

# %%
import matplotlib.pyplot as plt
import math

class LSystem2D:
    def __init__(self, axiom, width, length, angle):
        self.axiom = axiom
        self.state = axiom
        self.width = width
        self.length = length
        self.angle = angle
        self.rules = {}

    def add_rules(self, *rules):
        for key, value in rules:
            self.rules[key] = value

    def generate_path(self, n_iter):
        for _ in range(n_iter):
            new_state = ""
            for char in self.state:
                if char in self.rules:
                    new_state += self.rules[char].lower()
                else:
                    new_state += char
            self.state = new_state.upper()

    def draw_turtle(self, start_pos, start_angle):
        x, y = start_pos
        current_angle = start_angle

        lines_x = []
        lines_y = []

        for move in self.state:
            if move == 'F':
                new_x = x + self.length * math.cos(math.radians(current_angle))
                new_y = y + self.length * math.sin(math.radians(current_angle))
                lines_x.extend([x, new_x, None])
                lines_y.extend([y, new_y, None])
                x, y = new_x, new_y
            elif move == '+':
                current_angle += self.angle
            elif move == '-':
                current_angle -= self.angle

        plt.figure(figsize=(12, 12))
        plt.plot(lines_x, lines_y, linewidth=self.width)
        plt.axis("equal")
        plt.axis("off")
        plt.show()

# --- Основна частина ---
pen_width = 1
f_len = 5
angle = 60
axiom = "FX"

# Побудова кривої Госпера
l_sys = LSystem2D(axiom, pen_width, f_len, angle)
l_sys.add_rules(
    ("X", "X+YF++YF-FX--FXFX-YF+"),
    ("Y", "-FX+YFYF++YF+FX--FX-Y")
)
l_sys.generate_path(4)
l_sys.draw_turtle((0, 0), 0)
